# %%
import import_ipynb     #allows you to imports from different jupyter notebooks
from imports_a import *   #importing imports_a
# Out:
# importing Jupyter notebook from imports_a.ipynb

# %%
color = sns.color_palette()
sns.set_style('darkgrid')

def ignore_warn(*args, **kwargs):
    pass

warnings.warn = ignore_warn   #ignore annoying warning (from sklearn and seaborn)

# %%
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))   #Limiting floats output to 4 decimal points

# %%
print(check_output(["ls", "../data"]).decode("utf8"))     #check the files available in the directory
# Out:
# test.csv
# train.csv

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %%
train.shape
# Out:
# (1460, 81)

# %%
test.shape
# Out:
# (1459, 80)

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
print('Train size before droping ID: {}'.format(train.shape))
print('Test size before droping ID: {}'.format(test.shape))
#keep the ID for later usage
train_ID = train['Id']
test_ID = test['Id']
#now drop
train.drop(['Id', 'GarageArea', 'TotRmsAbvGrd'], axis=1, inplace=True)
test.drop(['Id', 'GarageArea', 'TotRmsAbvGrd'], axis=1, inplace=True)
print('Train after doroping ID: {}'.format(train.shape))
print('Test after doroping ID: {}'.format(test.shape))
# Out:
# Train size before droping ID: (1460, 81)
# Test size before droping ID: (1459, 80)
# Train after doroping ID: (1460, 78)
# Test after doroping ID: (1459, 77)

# %%
train.plot.scatter(x='GrLivArea', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
train = train.drop(train[(train.GrLivArea > 5000) & (train.SalePrice < 300000)].index)
train.plot.scatter(x='GrLivArea', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
train.plot.scatter(x='TotalBsmtSF', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %%
sns.distplot(train['SalePrice'], fit=norm)
(mu, sigma) = norm.fit(train['SalePrice'])
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f})'.format(mu, sigma)], loc='best')

fig = plt.figure()
res = stats.probplot(train['SalePrice'], plot=plt)

# %%
train['SalePrice'] = np.log1p(train['SalePrice'])

sns.distplot(train['SalePrice'], fit=norm)
(mu, sigma) = norm.fit(train['SalePrice'])
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f})'.format(mu, sigma)], loc='best')

fig = plt.figure()
res = stats.probplot(train['SalePrice'], plot=plt)

# %%
# before handling missing values let's concat train and test
ntrain = train.shape[0]
ntest = test.shape[0]
y_train = train.SalePrice.values
all_data = pd.concat((train, test)).reset_index(drop=True)
all_data.drop(['SalePrice'], axis=1, inplace=True)
all_data.shape
# Out:
# (2918, 77)

# %%
total = all_data.isnull().sum().sort_values(ascending=False)
perc = (all_data.isnull().sum() / all_data.isnull().count()).sort_values(ascending=False)
missing = pd.concat([total, perc], axis=1, keys=['Total', 'Ratio'])
missing[missing.Total > 0]
# Out:
#               Total  Ratio
# PoolQC         2909  0.997
# MiscFeature    2813  0.964
# Alley          2720  0.932
# Fence          2347  0.804
# FireplaceQu    1420  0.487
# LotFrontage     486  0.167
# GarageCond      159  0.054
# GarageFinish    159  0.054
# GarageYrBlt     159  0.054
# GarageQual      159  0.054
# GarageType      157  0.054
# BsmtExposure     82  0.028
# BsmtCond         82  0.028
# BsmtQual         81  0.028
# BsmtFinType2     80  0.027
# BsmtFinType1     79  0.027
# MasVnrType       24  0.008
# MasVnrArea       23  0.008
# MSZoning          4  0.001
# Functional        2  0.001
# BsmtFullBath      2  0.001
# BsmtHalfBath      2  0.001
# Utilities         2  0.001
# Exterior1st       1  0.000
# BsmtFinSF1        1  0.000
# SaleType          1  0.000
# KitchenQual       1  0.000
# Electrical        1  0.000
# TotalBsmtSF       1  0.000
# BsmtUnfSF         1  0.000
# Exterior2nd       1  0.000
# BsmtFinSF2        1  0.000
# GarageCars        1  0.000

# %%
all_data['LotFrontage'] = all_data.groupby('Neighborhood')['LotFrontage'].transform(lambda x: x.fillna(x.median()))

for col in ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 
            'GarageFinish', 'GarageQual', 'GarageCond', 'GarageType', 
            'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 
            'BsmtFinType2', 'MasVnrType', 'MSSubClass']:
    all_data[col] = all_data[col].fillna('None')
    
for col in ['GarageYrBlt', 'GarageCars', 'BsmtFinSF1', 'BsmtFinSF2', 'TotalBsmtSF', 'BsmtUnfSF', 'BsmtFullBath', 'BsmtHalfBath', 'MasVnrArea']:
    all_data[col] = all_data[col].fillna(0)
    
for col in ['MSZoning', 'Electrical', 'KitchenQual', 'Exterior1st', 'Exterior2nd', 'SaleType']:
    all_data[col] = all_data[col].fillna(all_data[col].mode()[0])
    
all_data = all_data.drop(['Utilities'], axis=1)

all_data['Functional'] = all_data['Functional'].fillna('Typ')

# %%
all_data.isnull().any().value_counts()
# Out:
# False    76
# dtype: int64

# %%
for col in ['OverallCond', 'YrSold', 'MoSold']:
    all_data[col] = all_data[col].astype(str)
    
all_data['MSSubClass'] = all_data['MSSubClass'].apply(str)

# %%
#transform non-numerical labels to numerical labels by LabelEncoder()
cols = ['FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 
        'ExterQual', 'ExterCond','HeatingQC', 'PoolQC', 'KitchenQual', 'BsmtFinType1', 
        'BsmtFinType2', 'Functional', 'Fence', 'BsmtExposure', 'GarageFinish', 'LandSlope',
        'LotShape', 'PavedDrive', 'Street', 'Alley', 'CentralAir', 'MSSubClass', 'OverallCond', 
        'YrSold', 'MoSold']

for col in cols:
    le = LabelEncoder()
    le.fit(list(all_data[col].values))
    all_data[col] = le.transform(list(all_data[col].values))
    
all_data.shape
# Out:
# (2918, 76)

# %%
all_data['TotalSF'] = all_data['TotalBsmtSF'] + all_data['1stFlrSF'] + all_data['2ndFlrSF']
all_data = all_data.drop(['TotalBsmtSF', '1stFlrSF', '2ndFlrSF'], axis=1)

# %%
numeric = all_data.dtypes[all_data.dtypes != 'object'].index

skewed_feats = all_data[numeric].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
skewness = pd.DataFrame({'skew':skewed_feats})
skewness.head(10)
# Out:
#                 skew
# MiscVal       21.943
# PoolArea      17.692
# LotArea       13.028
# LowQualFinSF  12.087
# 3SsnPorch     11.374
# LandSlope      4.974
# KitchenAbvGr   4.301
# BsmtFinSF2     4.145
# EnclosedPorch  4.003
# ScreenPorch    3.946

# %%
skewness = skewness[abs(skewness)>0.75]
skewed_features = skewness.index
lam = 0.15
for feat in skewed_features:
    #all_data[feat] += 1
    all_data[feat] = boxcox1p(all_data[feat], lam)
    
#all_data[skewed_features] = np.log1p(all_data[skewed_features])

# %%
all_data = pd.get_dummies(all_data)

# %%
all_data.shape
# Out:
# (2918, 215)

# %%
train = all_data[:ntrain]
test = all_data[ntrain:]
